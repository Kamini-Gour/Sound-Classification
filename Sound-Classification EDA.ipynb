# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename ='D:/archive/fold5/dog_bark.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 5ED3-A220
#
#  Directory of E:\UrbanSound8K
#
# 06/10/2023  12:15 AM    <DIR>          .
# 05/20/2014  12:28 AM            15,364 .DS_Store
# 06/10/2023  12:09 AM    <DIR>          .ipynb_checkpoints
# 05/20/2014  12:35 AM           705,644 100263-2-0-3.wav
# 05/28/2023  11:06 PM    <DIR>          audio
# 06/10/2023  12:01 AM           204,192 Audio Classification Data Preprocessing And Model Creation.ipynb
# 05/20/2014  12:45 AM            26,155 FREESOUNDCREDITS.txt
# 05/28/2023  11:07 PM    <DIR>          metadata
# 05/31/2023  10:18 PM    <DIR>          saved_models
# 06/10/2023  12:14 AM           174,901 Sound-Classification Data Preprocessing  & Model Creation.ipynb
# 06/10/2023  12:15 AM           979,518 Sound-Classification EDA.ipynb
# 06/04/2014  03:40 AM             4,932 UrbanSound8K_README.txt
#                7 File(s)      2,110,706 bytes
#                5 Dir(s)  459,196,989,440 bytes free

# %%
plt.figure(figsize=(14,5))
data,sample_rate = librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# sound
filename ='E:/UrbanSound8K/audio/fold1/7061-6-0-0.wav'
plt.figure(figsize=(14,5))
data,sample_rate = librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0],
#        ...,
#        [1, 0],
#        [1, 1],
#        [0, 0]], dtype=int16)

# %%
data
# Out:
# array([-7.4505806e-09,  2.9802322e-08,  4.8428774e-08, ...,
#         1.0127544e-05,  2.3271263e-05,  7.0009992e-06], dtype=float32)

# %%
import pandas as pd

metadata = pd.read_csv('E:\\UrbanSound8K\\metadata\\UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
##check weather dataset is imbalanced
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
